# %% [markdown]
# <b>#The Jupyter Notebook</b>

# %% [markdown]
# <b>The Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and narrative text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more.</b>

# %% [markdown]
# source : https://jupyter.org/

# %% [markdown]
# <video controls src="https://www.youtube.com/watch?v=e60ItwlZTKM" />

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'Interval',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Period',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseSeries',
#  'Term',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt64Index',
#  'WidePanel',
#  '_DeprecatedModule',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
#  '_np_version_under1p10',
#  '_np_version_under1p11',
#  '_np_version_under1p12',
#  '_np_version_under1p13',
#  '_np_version_under1p14',
#  '_np_version_under1p15',
#  '_tslib',
#  '_version',
#  'api',
# ...

# %%
df = pd.read_csv('free-zipcode-database.csv', delimiter = ',')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['RecordNumber', 'Zipcode', 'ZipCodeType', 'City', 'State',
#        'LocationType', 'Lat', 'Long', 'Xaxis', 'Yaxis', 'Zaxis', 'WorldRegion',
#        'Country', 'LocationText', 'Location', 'Decommisioned',
#        'TaxReturnsFiled', 'EstimatedPopulation', 'TotalWages', 'Notes'],
#       dtype='object')

# %%
df.head()
# Out:
#    RecordNumber  Zipcode ZipCodeType                 City State  \
# 0             1      704    STANDARD          PARC PARQUE    PR
# 1             2      704    STANDARD  PASEO COSTA DEL SUR    PR
# 2             3      704    STANDARD        SECT LANAUSSE    PR
# 3             4      704    STANDARD      URB EUGENE RICE    PR
# 4             5      704    STANDARD         URB GONZALEZ    PR
#
#      LocationType    Lat   Long  Xaxis  Yaxis  Zaxis WorldRegion Country  \
# 0  NOT ACCEPTABLE  17.96 -66.22   0.38  -0.87    0.3         NaN      US
# 1  NOT ACCEPTABLE  17.96 -66.22   0.38  -0.87    0.3         NaN      US
# 2  NOT ACCEPTABLE  17.96 -66.22   0.38  -0.87    0.3         NaN      US
# 3  NOT ACCEPTABLE  17.96 -66.22   0.38  -0.87    0.3         NaN      US
# 4  NOT ACCEPTABLE  17.96 -66.22   0.38  -0.87    0.3         NaN      US
#
#               LocationText                      Location  Decommisioned  \
# ...

# %%
df[df.State == 'TX']
# Out:
#        RecordNumber  Zipcode ZipCodeType                          City State  \
# 41221         41222    79821    STANDARD                       ANTHONY    TX
# 41222         41223    79821    STANDARD                        VINTON    TX
# 59913         59914    75001    STANDARD                       ADDISON    TX
# 59914         59915    75410    STANDARD                          ALBA    TX
# 59915         59916    75002    STANDARD                         ALLEN    TX
# 59916         59917    75002    STANDARD                         LUCAS    TX
# 59917         59918    75002    STANDARD                        PARKER    TX
# 59918         59919    75013    STANDARD                         ALLEN    TX
# 59919         59920    75925    STANDARD                          ALTO    TX
# 59920         59921    75925    STANDARD                        FOREST    TX
# 59921         59922    75925    STANDARD                       LINWOOD    TX
# ...

# %%
df[(df.State == 'TX') & (df.City == 'DALLAS')]
# Out:
#        RecordNumber  Zipcode ZipCodeType    City State LocationType    Lat  \
# 60076         60077    75201    STANDARD  DALLAS    TX      PRIMARY  32.79
# 60077         60078    75202    STANDARD  DALLAS    TX      PRIMARY  32.79
# 60078         60079    75203    STANDARD  DALLAS    TX      PRIMARY  32.79
# 60079         60080    75204    STANDARD  DALLAS    TX      PRIMARY  32.79
# 60080         60081    75205    STANDARD  DALLAS    TX      PRIMARY  32.79
# 60084         60085    75206    STANDARD  DALLAS    TX      PRIMARY  32.79
# 60085         60086    75207    STANDARD  DALLAS    TX      PRIMARY  32.79
# 60086         60087    75208    STANDARD  DALLAS    TX      PRIMARY  32.79
# 60087         60088    75209    STANDARD  DALLAS    TX      PRIMARY  32.79
# 60089         60090    75210    STANDARD  DALLAS    TX      PRIMARY  32.79
# 60090         60091    75211    STANDARD  DALLAS    TX      PRIMARY  32.79
# ...

# %%
df.count()
# Out:
# RecordNumber           81831
# Zipcode                81831
# ZipCodeType            81831
# City                   81831
# State                  81831
# LocationType           81831
# Lat                    81178
# Long                   81178
# Xaxis                  81831
# Yaxis                  81831
# Zaxis                  81831
# WorldRegion              334
# Country                81831
# LocationText           81180
# Location               81830
# Decommisioned          81831
# TaxReturnsFiled        58447
# EstimatedPopulation    58447
# TotalWages             58354
# Notes                   1844
# dtype: int64

# %%
df.Zipcode.count()
# Out:
# 81831

# %%
df[['Zipcode', 'TotalWages']].count()
# Out:
# Zipcode       81831
# TotalWages    58354
# dtype: int64

# %%
df.isna().sum()
# Out:
# RecordNumber               0
# Zipcode                    0
# ZipCodeType                0
# City                       0
# State                      0
# LocationType               0
# Lat                      653
# Long                     653
# Xaxis                      0
# Yaxis                      0
# Zaxis                      0
# WorldRegion            81497
# Country                    0
# LocationText             651
# Location                   1
# Decommisioned              0
# TaxReturnsFiled        23384
# EstimatedPopulation    23384
# TotalWages             23477
# Notes                  79987
# dtype: int64

# %%
df.WorldRegion.unique()
# Out:
# array([nan, 'EU', 'ME', 'AS', 'CA', 'AF', 'SA', 'AU', 'WW'], dtype=object)

# %%
df.WorldRegion.value_counts()
# Out:
# EU    147
# AS     81
# ME     80
# CA      8
# AF      7
# AU      6
# SA      4
# WW      1
# Name: WorldRegion, dtype: int64

# %%
df.WorldRegion.value_counts(dropna=False)
# Out:
# NaN    81497
# EU       147
# AS        81
# ME        80
# CA         8
# AF         7
# AU         6
# SA         4
# WW         1
# Name: WorldRegion, dtype: int64

# %%
df.Lat.value_counts(bins=4)
# Out:
# (13.515, 42.398]      65142
# (42.398, 71.28]       15982
# (-15.368, 13.515]        53
# (-44.367, -15.368]        1
# Name: Lat, dtype: int64

# %%
71.28 - 32.77
# Out:
# 38.51

# %%
32.77 + 5.74
# Out:
# 38.510000000000005

# %%
-44.367 + 5.74
# Out:
# -38.626999999999995

# %%
df.TotalWages.value_counts(bins=3)
# Out:
# (-2132869.893, 710956630.667]      53374
# (710956630.667, 1421913261.333]     4474
# (1421913261.333, 2132869892.0]       506
# Name: TotalWages, dtype: int64

# %%
df2 = df[['TotalWages']].head(1000) #'TaxReturnsFiled', 'EstimatedPopulation',

# %%
df2.count()
# Out:
# TotalWages    177
# dtype: int64

# %%
df2.TotalWages.value_counts(dropna=False)
# Out:
# NaN              823
#  1.394042e+09      7
#  1.031960e+09      6
#  4.509563e+08      5
#  1.114306e+09      5
#  9.189192e+08      5
#  1.529645e+09      5
#  1.143187e+09      4
#  8.810873e+08      4
#  1.089095e+09      4
#  1.017557e+09      4
#  2.084544e+09      4
#  1.572037e+09      4
#  7.315346e+08      4
#  1.685441e+09      4
#  7.235085e+08      4
#  8.397657e+08      4
#  7.180687e+08      4
#  7.915783e+08      4
#  2.400756e+08      4
#  3.457693e+08      4
#  1.108944e+09      4
#  5.318074e+08      3
#  1.412439e+09      3
#  4.140217e+08      3
#  1.675737e+09      3
#  4.013124e+08      3
#  1.050141e+09      3
#  2.073635e+08      3
#  8.100268e+08      3
#                 ...
#  1.270484e+09      3
#  9.643575e+08      3
#  1.284853e+09      3
#  7.547549e+08      3
#  9.247761e+08      2
#  8.406129e+08      2
#  3.252742e+08      2
#  3.336234e+08      2
#  6.238277e+08      2
#  1.071976e+09      2
#  2.731196e+08      2
#  7.329075e+08      2
# ...

# %%
import numpy as np

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.460952  0.556442  0.367485  0.304167
# 1  0.754515  0.727436  0.196235  0.519195
# 2  0.203100  0.599496  0.687409  0.431344
# 3  0.898871  0.584432  0.156719  0.046593
# 4  0.051657  0.464992  0.553532  0.990864

# %%
df2.to_csv('output-df2.csv')

# %%
df2.to_pickle('output-df2.pkl')

# %%
df3 = pd.read_pickle('output-df2.pkl')

# %%
# Out:
#           a         b         c         d
# 0  0.460952  0.556442  0.367485  0.304167
# 1  0.754515  0.727436  0.196235  0.519195
# 2  0.203100  0.599496  0.687409  0.431344
# 3  0.898871  0.584432  0.156719  0.046593
# 4  0.051657  0.464992  0.553532  0.990864
# 5  0.040662  0.029340  0.327158  0.630300
# 6  0.725157  0.578720  0.959339  0.742613
# 7  0.958015  0.155126  0.866700  0.953658
# 8  0.828515  0.369726  0.684863  0.555738
# 9  0.852941  0.342976  0.855885  0.886440

# %%
df2.plot.bar()

# %%
df2.plot.bar()
